# %%
# %run executeWind.py
# Out:
# Reading image.out

# %%
# image.makeImage(npix=300., wav=28, incl=0., phi=0., sizeau=300.)
# im = image.readImage()
# image.plotImage(im, au=True, log=True, maxlog=10, saturate=1e-5) #, cmap=plb.cm.gist_heat)
# %run executeWind.py
# Out:
# Reading image.out
